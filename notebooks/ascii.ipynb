# %% [markdown]
# ### trying different figlet fonts

# %%
from pyfiglet import FigletFont,figlet_format
"""
for font in FigletFont.getFonts():
  name = figlet_format(
    'Claude Code CLI',
    font=font
  )"""

name = figlet_format('Claude Code',font='slant',width=180)
print(name)
print()
# Out:
#    ________                __        ______          __
#   / ____/ /___ ___  ______/ /__     / ____/___  ____/ /__
#  / /   / / __ `/ / / / __  / _ \   / /   / __ \/ __  / _ \
# / /___/ / /_/ / /_/ / /_/ /  __/  / /___/ /_/ / /_/ /  __/
# \____/_/\__,_/\__,_/\__,_/\___/   \____/\____/\__,_/\___/
